# %% [markdown]
# # Grid Search & Cross Validation
#
# Topics Covered:
# * Cross Validation Resampling Methods
# * K-Fold Cross Validation
# * Big-O Notation - Model Runtime Estimation

# %% [markdown]
# ## K-Fold Cross Validation
#
# If you have a machine learning model and some data, you want to tell if your model can fit. You can split your data into training and test set. Train your model with the training set and evaluate the result with test set. But you evaluated the model only once and you are not sure your good result is by luck or not. You want to evaluate the model multiple times so you can be more confident about the model design.
#
# The procedure has a single parameter called k that refers to the number of groups that a given data sample is to be split into. As such, the procedure is often called k-fold cross-validation. When a specific value for k is chosen, it may be used in place of k in the reference to the model, such as k=10 becoming 10-fold cross-validation.
#
# Cross-validation is primarily used in applied machine learning to estimate the skill of a machine learning model on unseen data. That is, to use a limited sample in order to estimate how the model is expected to perform in general when used to make predictions on data not used during the training of the model.
#
# [Source: MachineLearningMastery](https://machinelearningmastery.com/k-fold-cross-validation/)

# %% [markdown]
# ![grid_search_cross_validation.png](attachment:grid_search_cross_validation.png)

# %% [markdown]
# ![1_chD302ssE0O62wreunGp4A.jpg](attachment:1_chD302ssE0O62wreunGp4A.jpg)

# %% [markdown]
# **NOTE:** A model is "refit" with all of the training set data at the end of the k-fold validation. The performance estimate is a summary of the performance across all the folds.

# %% [markdown]
# ![featured.png](attachment:featured.png)

# %% [markdown]
# See the breast cancer example from Modeling Methodology for example of implemenatation

# %% [markdown]
# ## Grid Search
#
# A model hyperparameter is a characteristic of a model that is external to the model and whose value cannot be estimated from data. The value of the hyperparameter has to be set before the learning process begins. For example, c in Support Vector Machines, k in k-Nearest Neighbors, the number of hidden layers in Neural Networks.
#
# In contrast, a parameter is an internal characteristic of the model and its value can be estimated from data. Example, beta coefficients of linear/logistic regression or support vectors in Support Vector Machines.
#
# Grid-search is used to find the optimal hyperparameters of a model which results in the most ‘accurate’ predictions.
#
#
# [Source: TowardsDataScience](https://towardsdatascience.com/grid-search-for-model-tuning-3319b259367e)

# %% [markdown]
# **NOTE:** The intent behind grid search is to maximize or minimize an objective function. The goal is to select model hyperparameters to best achieve your objective function.

# %% [markdown]
# ![ac3f2f5a-9199-4bb7-8ce6-47e4dc307a0e.png](attachment:ac3f2f5a-9199-4bb7-8ce6-47e4dc307a0e.png)

# %% [markdown]
# Key Terms & Concepts:
# * Objective Function
# * Hypterparmaeters
# * Tuning or Hyper-tuning
# * Hypterparameter Optimization

# %% [markdown]
# Advanced Topics:
# * Random Search: https://machinelearningmastery.com/hyperparameter-optimization-with-random-search-and-grid-search/

# %% [markdown]
# ![1_sPTZiXuWHBct_kYiD_5aYA.jpg](attachment:1_sPTZiXuWHBct_kYiD_5aYA.jpg)
