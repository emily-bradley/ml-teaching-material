# %% [markdown]
# # Intro to Modeling Metrics: Classification
#
# A useful learning source: https://medium.com/@impythonprogrammer/evaluation-metrics-for-classification-fc770511052d

# %% [markdown]
# ## Classification: Accuracy and Confusion Matrix

# %% [markdown]
# ### Accuracy
#
# Accuracy = (TP+TN)/(TP+FP+FN+TN)
#
# Accuracy is the proportion of true results among the total number of cases examined.

# %% [markdown]
# When to use?
# Accuracy is a valid choice of evaluation for classification problems which are well balanced and not skewed or No class imbalance.
#
# Caveats
# Let us say that our target class is very sparse. Do we want accuracy as a metric of our model performance? What if we are predicting if an asteroid will hit the earth? Just say No all the time. And you will be 99% accurate. My model can be reasonably accurate, but not at all valuable.
#
# [Source](https://towardsdatascience.com/the-5-classification-evaluation-metrics-you-must-know-aa97784ff226)

# %% [markdown]
# ### Confusion Matrix: Precision and Recall

# %% [markdown]
# ![image-35.png](attachment:image-35.png)

# %% [markdown]
# ![feature.png](attachment:feature.png)

# %% [markdown]
# ### Precision
#
# Precision = (TP)/(TP+FP)
#
# Of all of our positive predictions, how many were correct?
#
# When we predicted someone had cancer, how many times did they have cancer?
#
# When to use?
# Precision is a valid choice of evaluation metric when we want to be very sure of our prediction. For example: If we are building a system to predict if we should decrease the credit limit on a particular account, we want to be very sure about our prediction or it may result in customer dissatisfaction.

# %% [markdown]
# ### Recall
#
# Recall = (TP)/(TP+FN)
#
# Of all the true positive values, how many did you correctly identify?
#
# Out of everyone who did have cancer, how many did we correctly identify? Were there some people who had cancer that we said did not?
#
# When to use?
# Recall is a valid choice of evaluation metric when we want to capture as many positives as possible. For example: If we are building a system to predict if a person has cancer or not, we want to capture the disease even if we are not very sure.

# %% [markdown]
# ![1_H_XIN0mknyo0Maw4pKdQhw.png](attachment:1_H_XIN0mknyo0Maw4pKdQhw.png)

# %% [markdown]
# ## F1 Score
#
# The F1 score is a number between 0 and 1 and is the **harmonic mean of precision and recall**.
#
# where precision is the proportion of true positive instances among all the instances predicted as positive, and recall is the proportion of true positive instances among all the actual positive instances.

# %% [markdown]
# ![1_7tC4-fUHtcffvXGcGTJJtg.png](attachment:1_7tC4-fUHtcffvXGcGTJJtg.png)

# %% [markdown]
# ## F Beta - Generalized F1 Score

# %% [markdown]
# ![download-1.jpg](attachment:download-1.jpg)

# %% [markdown]
# ![swW0x.png](attachment:swW0x.png)

# %% [markdown]
# ![f-beta.jpg](attachment:f-beta.jpg)
