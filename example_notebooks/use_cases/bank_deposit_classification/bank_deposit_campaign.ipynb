# %% [markdown]
# # Predicting Effect of Marketing Campaign

# %% [markdown]
# Input variables:
#
# bank client data:
#    * age (numeric)
#    * job : type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student",
#                                        "blue-collar","self-employed","retired","technician","services")
#    * marital : marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed)
#    * education (categorical: "unknown","secondary","primary","tertiary")
#    * default: has credit in default? (binary: "yes","no")
#    * balance: average yearly balance, in euros (numeric)
#    * housing: has housing loan? (binary: "yes","no")
#    * loan: has personal loan? (binary: "yes","no")
#
# related with the last contact of the current campaign:
#    * contact: contact communication type (categorical: "unknown","telephone","cellular")
#    * day: last contact day of the month (numeric)
#    * month: last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec")
#    * duration: last contact duration, in seconds (numeric)
#
# other attributes:
#    * campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
#    * pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted)
#    * previous: number of contacts performed before this campaign and for this client (numeric)
#    * poutcome: outcome of the previous marketing campaign (categorical: "unknown","other","failure","success")
#
# Output variable (desired target):
#    * y - has the client subscribed a term deposit? (binary: "yes","no")

# %% [markdown]
# Source: https://archive.ics.uci.edu/ml/datasets/bank+marketing

# %% [markdown]
# # Import required packages

# %%
from datetime import datetime
import numpy as np
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator
from joblib import dump, load
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Set the parameters for the run

# %%
model_name = 'bank_deposit_campaign.joblib'

# %% [markdown]
# # Get the data

# %%
df = pd.read_csv('bank.csv', sep=';')

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
df.rename(columns={'y':'subscribed'}, inplace=True)

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  cellular   19   oct        79         1     -1         0  unknown
# 1  cellular   11   may       220         1    339         4  failure
# 2  cellular   16   apr       185         1    330         1  failure
# 3   unknown    3   jun       199         4     -1         0  unknown
# 4   unknown    5   may       226         1     -1         0  unknown
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no

# %%
df.dtypes
# Out:
# age            int64
# job           object
# marital       object
# education     object
# default       object
# balance        int64
# housing       object
# loan          object
# contact       object
# day            int64
# month         object
# duration       int64
# campaign       int64
# pdays          int64
# previous       int64
# poutcome      object
# subscribed    object
# dtype: object

# %% [markdown]
# # Train Test Split

# %%
y = df['subscribed']
X = df.drop('subscribed', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

# %% [markdown]
# # Exploratory Data Analysis

# %%
y_train.head()
# Out:
# 3480    no
# 3344    no
# 1939    no
# 834     no
# 3715    no
# Name: subscribed, dtype: object

# %%
type(y_train[1])
# Out:
# str

# %%
y_train.value_counts()
# Out:
# no     2788
# yes     376
# Name: subscribed, dtype: int64

# %%
# The y value is a string, convert to int
y_train.astype(int).head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-53403bd70c23> in <module>()
#       1 # The y value is a string, convert to int
# ----> 2 y_train.astype(int).head()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#      89                 else:
#      90                     kwargs[new_arg_name] = new_arg_value
# ---> 91             return func(*args, **kwargs)
#      92         return wrapper
#      93     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    3408         # else, only a single dtype is given
#    3409         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 3410                                      **kwargs)
#    3411         return self._constructor(new_data).__finalize__(self)
#    3412
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3222
#    3223     def astype(self, dtype, **kwargs):
# -> 3224         return self.apply('astype', dtype=dtype, **kwargs)
#    3225
#    3226     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3089
#    3090             kwargs['mgr'] = self
# -> 3091             applied = getattr(b, f)(**kwargs)
#    3092             result_blocks = _extend_blocks(applied, result_blocks)
#    3093
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     469     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     470         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 471                             **kwargs)
#     472
#     473     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, raise_on_error, **kwargs)
#     519
#     520                 # _astype_nansafe works fine with 1-d only
# --> 521                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     522                 values = values.reshape(self.shape)
#     523
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     623     elif arr.dtype == np.object_ and np.issubdtype(dtype.type, np.integer):
#     624         # work around NumPy brokenness, #1987
# --> 625         return lib.astype_intsafe(arr.ravel(), dtype).reshape(arr.shape)
#     626
#     627     if dtype.name in ("datetime64", "timedelta64"):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.astype_intsafe()
#
# pandas/_libs/src/util.pxd in util.set_value_at_unsafe()
#
# ValueError: invalid literal for int() with base 10: 'no'

# %%
y_train.describe()
# Out:
# count    105000.000000
# mean          0.066857
# std           0.249776
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: SeriousDlqin2yrs, dtype: float64

# %%
len(X_train)
# Out:
# 105000

# %% [markdown]
# # Set up the model pipeline

# %%
pipeline = Pipeline(steps=[
    ('impute_mean', ColumnTransformer(transformers=[
                        ('scalar imputing mean', SimpleImputer(strategy='mean'), X_train.columns),
                        ], remainder='drop')),
    ('scale', ColumnTransformer(transformers=[
                        ('scalar scaling', MinMaxScaler(feature_range=(0, 1)), np.arange(0, len(X_train.columns))),
                        ], remainder='drop')),
    ('GBT', GradientBoostingClassifier())
    ])

# %% [markdown]
# # Set up the grid Search

# %% [markdown]
# Set the parameters for a grid search over the selected family of models.

# %%
# Currently only contains default values.  Commented parameters needn't be used
# in a grid search.
dct_grid = {
    'GBT__n_estimators' : [25, 50, 100],
    'GBT__max_depth'    : [2, 5, 9]
}

# %% [raw]
# # Default values for `GradientBoostingClassifier`.
# dct_grid = {
#     'loss'                     : ['deviance'],
#     'learning_rate'            : [0.1],
#     'n_estimators'             : [100],
#     'subsample'                : [1.0],
#     'criterion'                : ['friedman_mse'],
#     'min_samples_split'        : [2],
#     'min_samples_leaf'         : [1],
#     'min_weight_fraction_leaf' : [0.0],
#     'max_depth'                : [3],
#     'min_impurity_decrease'    : [0.0],
#     'init'                     : [None],
#     'random_state'             : [None],
#     'max_features'             : [None],
#     'verbose'                  : [0],
#     'max_leaf_nodes'           : [None],
#     'warm_start'               : [False],
#     'presort'                  : ['auto'],
#     'validation_fraction'      : [0.1],
#     'n_iter_no_change'         : [None],
#     'tol'                      : [0.0001]
# }

# %% [markdown]
# Search for the best model.

# %%
grid_search = GridSearchCV(pipeline, dct_grid, cv=10, return_train_score=False
                   , scoring=['accuracy', 'precision', 'average_precision', 'neg_log_loss']
                   , refit='average_precision', n_jobs=-1 )
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('impute_mean',
#                                         ColumnTransformer(n_jobs=None,
#                                                           remainder='drop',
#                                                           sparse_threshold=0.3,
#                                                           transformer_weights=None,
#                                                           transformers=[('scalar '
#                                                                          'imputing '
#                                                                          'mean',
#                                                                          SimpleImputer(add_indicator=False,
#                                                                                        copy=True,
#                                                                                        fill_value=None,
#                                                                                        missing_values=nan,
#                                                                                        strategy='mean',
#                                                                                        verbose=0),
#                                                                          Index([...
#                                                                    random_state=None,
#                                                                    subsample=1.0,
#                                                                    tol=0.0001,
#                                                                    validation_fraction=0.1,
#                                                                    verbose=0,
#                                                                    warm_start=False))],
#                                 verbose=False),
#              iid='warn', n_jobs=-1,
#              param_grid={'GBT__max_depth': [2, 5, 9],
#                          'GBT__n_estimators': [25, 50, 100]},
#              pre_dispatch='2*n_jobs', refit='average_precision',
#              return_train_score=False,
#              scoring=['accuracy', 'precision', 'average_precision',
#                       'neg_log_loss'],
#              verbose=0)

# %% [markdown]
# # Time of Run

# %%
pd.DataFrame(grid_search.cv_results_)['mean_fit_time']
# Out:
# 0      2.771568
# 1      4.582119
# 2      8.994104
# 3      7.313626
# 4     15.102574
# 5     29.684747
# 6     44.170989
# 7     75.898678
# 8    111.161170
# Name: mean_fit_time, dtype: float64

# %%
time_of_run_in_hours = (pd.DataFrame(grid_search.cv_results_)['mean_fit_time'] * 10).sum() / 60 / 60
print('time of run in hours: {}'.format(time_of_run_in_hours))
hours_per_record = time_of_run_in_hours / 20000
print('hours per record: {}'.format(hours_per_record))
records_in_an_hour = 1 / hours_per_record
print('number of records in 1 hour {}'.format(records_in_an_hour))
# Out:
# time of run in hours: 0.8324432647228241
# hours per record: 4.1622163236141207e-05
# number of records in 1 hour 24025.66138445403

# %% [markdown]
# # Analyze the Model Results

# %%
pd.DataFrame(grid_search.cv_results_).T
# Out:
#                                                                             0  \
# mean_fit_time                                                         2.77157
# mean_score_time                                                     0.0563925
# mean_test_accuracy                                                     0.9358
# mean_test_average_precision                                          0.344293
# mean_test_neg_log_loss                                              -0.194948
# mean_test_precision                                                  0.615378
# param_GBT__max_depth                                                        2
# param_GBT__n_estimators                                                    25
# params                         {'GBT__max_depth': 2, 'GBT__n_estimators': 25}
# rank_test_accuracy                                                          6
# rank_test_average_precision                                                 8
# rank_test_neg_log_loss                                                      9
# rank_test_precision                                                         2
# split0_test_accuracy                                                 0.937619
# split0_test_average_precision                                        0.368293
# split0_test_neg_log_loss                                            -0.194131
# split0_test_precision                                                   0.688
# split1_test_accuracy                                                 0.934571
# split1_test_average_precision                                        0.343027
# split1_test_neg_log_loss                                            -0.194567
# split1_test_precision                                                0.564103
# split2_test_accuracy                                                 0.937048
# split2_test_average_precision                                        0.352353
# split2_test_neg_log_loss                                            -0.196218
# split2_test_precision                                                0.672269
# split3_test_accuracy                                                  0.93381
# split3_test_average_precision                                        0.325208
# split3_test_neg_log_loss                                            -0.197486
# split3_test_precision                                                0.529412
# split4_test_accuracy                                                 0.934476
# split4_test_average_precision                                        0.324256
# split4_test_neg_log_loss                                             -0.19669
# split4_test_precision                                                0.567308
# split5_test_accuracy                                                 0.934381
# split5_test_average_precision                                        0.333142
# split5_test_neg_log_loss                                            -0.194608
# split5_test_precision                                                0.556522
# split6_test_accuracy                                                 0.936286
# split6_test_average_precision                                        0.353427
# split6_test_neg_log_loss                                            -0.193697
# split6_test_precision                                                   0.632
# split7_test_accuracy                                                 0.937429
# split7_test_average_precision                                        0.358031
# split7_test_neg_log_loss                                            -0.193641
# split7_test_precision                                                0.692308
# split8_test_accuracy                                                    0.936
# split8_test_average_precision                                        0.340681
# split8_test_neg_log_loss                                            -0.194635
# split8_test_precision                                                0.619048
# split9_test_accuracy                                                 0.936381
# split9_test_average_precision                                        0.344516
# split9_test_neg_log_loss                                            -0.193805
# split9_test_precision                                                0.632812
# std_fit_time                                                         0.199249
# std_score_time                                                     0.00355107
# std_test_accuracy                                                   0.0013179
# std_test_average_precision                                           0.013483
# std_test_neg_log_loss                                              0.00129205
# std_test_precision                                                  0.0555127
#
#                                                                             1  \
# mean_fit_time                                                         4.58212
# mean_score_time                                                     0.0743516
# mean_test_accuracy                                                   0.937057
# mean_test_average_precision                                          0.362574
# mean_test_neg_log_loss                                              -0.191332
# mean_test_precision                                                  0.621309
# param_GBT__max_depth                                                        2
# param_GBT__n_estimators                                                    50
# params                         {'GBT__max_depth': 2, 'GBT__n_estimators': 50}
# rank_test_accuracy                                                          2
# rank_test_average_precision                                                 5
# rank_test_neg_log_loss                                                      8
# rank_test_precision                                                         1
# split0_test_accuracy                                                 0.938476
# split0_test_average_precision                                         0.38323
# split0_test_neg_log_loss                                            -0.190312
# split0_test_precision                                                   0.675
# split1_test_accuracy                                                 0.936857
# split1_test_average_precision                                        0.358591
# split1_test_neg_log_loss                                             -0.19128
# split1_test_precision                                                0.615385
# split2_test_accuracy                                                 0.937429
# split2_test_average_precision                                        0.368144
# split2_test_neg_log_loss                                            -0.193078
# split2_test_precision                                                0.643312
# split3_test_accuracy                                                 0.934381
# split3_test_average_precision                                        0.345261
# split3_test_neg_log_loss                                            -0.193853
# split3_test_precision                                                0.539877
# split4_test_accuracy                                                 0.935714
# split4_test_average_precision                                        0.335912
# split4_test_neg_log_loss                                            -0.193339
# split4_test_precision                                                0.588235
# split5_test_accuracy                                                  0.93619
# split5_test_average_precision                                         0.35114
# split5_test_neg_log_loss                                            -0.190965
# split5_test_precision                                                0.594118
# split6_test_accuracy                                                 0.938857
# split6_test_average_precision                                        0.375756
# split6_test_neg_log_loss                                            -0.189594
# split6_test_precision                                                0.666667
# split7_test_accuracy                                                 0.939524
# split7_test_average_precision                                        0.378274
# split7_test_neg_log_loss                                            -0.189698
# split7_test_precision                                                0.689266
# split8_test_accuracy                                                 0.935905
# split8_test_average_precision                                        0.364913
# split8_test_neg_log_loss                                            -0.190535
# split8_test_precision                                                0.578378
# split9_test_accuracy                                                 0.937238
# split9_test_average_precision                                         0.36452
# split9_test_neg_log_loss                                            -0.190663
# split9_test_precision                                                0.622857
# std_fit_time                                                        0.0558229
# std_score_time                                                     0.00380542
# std_test_accuracy                                                   0.0015031
# std_test_average_precision                                          0.0142981
# std_test_neg_log_loss                                              0.00146223
# std_test_precision                                                  0.0451521
#
#                                                                              2  \
# mean_fit_time                                                           8.9941
# mean_score_time                                                      0.0943837
# mean_test_accuracy                                                    0.937238
# mean_test_average_precision                                           0.368537
# mean_test_neg_log_loss                                               -0.189446
# mean_test_precision                                                   0.606148
# param_GBT__max_depth                                                         2
# param_GBT__n_estimators                                                    100
# params                         {'GBT__max_depth': 2, 'GBT__n_estimators': 100}
# rank_test_accuracy                                                           1
# rank_test_average_precision                                                  4
# rank_test_neg_log_loss                                                       6
# rank_test_precision                                                          4
# split0_test_accuracy                                                  0.939524
# split0_test_average_precision                                         0.385515
# split0_test_neg_log_loss                                             -0.187877
# split0_test_precision                                                 0.666667
# split1_test_accuracy                                                  0.936952
# split1_test_average_precision                                         0.365243
# split1_test_neg_log_loss                                             -0.189516
# split1_test_precision                                                  0.59901
# split2_test_accuracy                                                  0.937619
# split2_test_average_precision                                          0.37003
# split2_test_neg_log_loss                                             -0.191383
# split2_test_precision                                                 0.619289
# split3_test_accuracy                                                  0.934571
# split3_test_average_precision                                         0.351371
# split3_test_neg_log_loss                                             -0.191881
# split3_test_precision                                                 0.539683
# split4_test_accuracy                                                  0.935524
# split4_test_average_precision                                         0.338957
# split4_test_neg_log_loss                                             -0.192267
# split4_test_precision                                                 0.568306
# split5_test_accuracy                                                   0.93581
# split5_test_average_precision                                         0.359325
# split5_test_neg_log_loss                                             -0.188792
# split5_test_precision                                                 0.567961
# split6_test_accuracy                                                  0.938286
# split6_test_average_precision                                         0.380431
# split6_test_neg_log_loss                                             -0.187788
# split6_test_precision                                                 0.626168
# split7_test_accuracy                                                  0.940095
# split7_test_average_precision                                         0.389488
# split7_test_neg_log_loss                                             -0.187309
# split7_test_precision                                                 0.679803
# split8_test_accuracy                                                  0.936476
# split8_test_average_precision                                         0.372964
# split8_test_neg_log_loss                                             -0.188317
# split8_test_precision                                                 0.582938
# split9_test_accuracy                                                  0.937524
# split9_test_average_precision                                         0.372043
# split9_test_neg_log_loss                                             -0.189327
# split9_test_precision                                                  0.61165
# std_fit_time                                                         0.0855453
# std_score_time                                                      0.00396804
# std_test_accuracy                                                   0.00165725
# std_test_average_precision                                           0.0147247
# std_test_neg_log_loss                                               0.00170707
# std_test_precision                                                   0.0419391
#
#                                                                             3  \
# mean_fit_time                                                         7.31363
# mean_score_time                                                     0.0737344
# mean_test_accuracy                                                   0.936543
# mean_test_average_precision                                          0.372784
# mean_test_neg_log_loss                                              -0.188682
# mean_test_precision                                                    0.6072
# param_GBT__max_depth                                                        5
# param_GBT__n_estimators                                                    25
# params                         {'GBT__max_depth': 5, 'GBT__n_estimators': 25}
# rank_test_accuracy                                                          4
# rank_test_average_precision                                                 3
# rank_test_neg_log_loss                                                      4
# rank_test_precision                                                         3
# split0_test_accuracy                                                 0.938286
# split0_test_average_precision                                        0.392953
# split0_test_neg_log_loss                                             -0.18786
# split0_test_precision                                                0.662651
# split1_test_accuracy                                                 0.935905
# split1_test_average_precision                                        0.369884
# split1_test_neg_log_loss                                            -0.188802
# split1_test_precision                                                0.582857
# split2_test_accuracy                                                 0.938381
# split2_test_average_precision                                         0.37733
# split2_test_neg_log_loss                                            -0.190552
# split2_test_precision                                                0.664671
# split3_test_accuracy                                                 0.934095
# split3_test_average_precision                                        0.354595
# split3_test_neg_log_loss                                            -0.190832
# split3_test_precision                                                0.529412
# split4_test_accuracy                                                 0.935143
# split4_test_average_precision                                        0.345499
# split4_test_neg_log_loss                                            -0.192001
# split4_test_precision                                                0.560694
# split5_test_accuracy                                                 0.935905
# split5_test_average_precision                                        0.365529
# split5_test_neg_log_loss                                            -0.186883
# split5_test_precision                                                0.588957
# split6_test_accuracy                                                 0.936667
# split6_test_average_precision                                        0.384074
# split6_test_neg_log_loss                                            -0.187245
# split6_test_precision                                                0.610778
# split7_test_accuracy                                                 0.938095
# split7_test_average_precision                                        0.385564
# split7_test_neg_log_loss                                            -0.187038
# split7_test_precision                                                0.675676
# split8_test_accuracy                                                 0.936857
# split8_test_average_precision                                        0.381823
# split8_test_neg_log_loss                                            -0.186855
# split8_test_precision                                                0.607735
# split9_test_accuracy                                                 0.936095
# split9_test_average_precision                                        0.370585
# split9_test_neg_log_loss                                            -0.188755
# split9_test_precision                                                0.588571
# std_fit_time                                                          0.11647
# std_score_time                                                     0.00266242
# std_test_accuracy                                                  0.00133812
# std_test_average_precision                                          0.0139325
# std_test_neg_log_loss                                              0.00176573
# std_test_precision                                                  0.0453497
#
#                                                                             4  \
# mean_fit_time                                                         15.1026
# mean_score_time                                                       0.11627
# mean_test_accuracy                                                   0.936657
# mean_test_average_precision                                          0.375265
# mean_test_neg_log_loss                                              -0.186317
# mean_test_precision                                                  0.582789
# param_GBT__max_depth                                                        5
# param_GBT__n_estimators                                                    50
# params                         {'GBT__max_depth': 5, 'GBT__n_estimators': 50}
# rank_test_accuracy                                                          3
# rank_test_average_precision                                                 1
# rank_test_neg_log_loss                                                      2
# rank_test_precision                                                         5
# split0_test_accuracy                                                 0.938571
# split0_test_average_precision                                        0.395702
# split0_test_neg_log_loss                                            -0.184311
# split0_test_precision                                                0.628959
# split1_test_accuracy                                                 0.936476
# split1_test_average_precision                                        0.373369
# split1_test_neg_log_loss                                             -0.18613
# split1_test_precision                                                0.578475
# split2_test_accuracy                                                 0.938381
# split2_test_average_precision                                        0.374528
# split2_test_neg_log_loss                                            -0.188579
# split2_test_precision                                                0.623318
# split3_test_accuracy                                                 0.934476
# split3_test_average_precision                                        0.352745
# split3_test_neg_log_loss                                             -0.18905
# split3_test_precision                                                0.530973
# split4_test_accuracy                                                 0.935048
# split4_test_average_precision                                        0.345782
# split4_test_neg_log_loss                                            -0.190359
# split4_test_precision                                                0.546729
# split5_test_accuracy                                                 0.935714
# split5_test_average_precision                                        0.374215
# split5_test_neg_log_loss                                            -0.184231
# split5_test_precision                                                0.561644
# split6_test_accuracy                                                 0.936952
# split6_test_average_precision                                        0.382755
# split6_test_neg_log_loss                                             -0.18499
# split6_test_precision                                                0.595238
# split7_test_accuracy                                                  0.93819
# split7_test_average_precision                                        0.394938
# split7_test_neg_log_loss                                            -0.184081
# split7_test_precision                                                0.618834
# split8_test_accuracy                                                 0.937048
# split8_test_average_precision                                        0.388131
# split8_test_neg_log_loss                                            -0.183882
# split8_test_precision                                                0.585774
# split9_test_accuracy                                                 0.935714
# split9_test_average_precision                                        0.370481
# split9_test_neg_log_loss                                            -0.187557
# split9_test_precision                                                 0.55794
# std_fit_time                                                         0.294571
# std_score_time                                                     0.00656567
# std_test_accuracy                                                   0.0013559
# std_test_average_precision                                          0.0155913
# std_test_neg_log_loss                                              0.00227061
# std_test_precision                                                  0.0321027
#
#                                                                              5  \
# mean_fit_time                                                          29.6847
# mean_score_time                                                       0.171288
# mean_test_accuracy                                                    0.936533
# mean_test_average_precision                                           0.372893
# mean_test_neg_log_loss                                               -0.185873
# mean_test_precision                                                   0.574893
# param_GBT__max_depth                                                         5
# param_GBT__n_estimators                                                    100
# params                         {'GBT__max_depth': 5, 'GBT__n_estimators': 100}
# rank_test_accuracy                                                           5
# rank_test_average_precision                                                  2
# rank_test_neg_log_loss                                                       1
# rank_test_precision                                                          6
# split0_test_accuracy                                                   0.93781
# split0_test_average_precision                                         0.392826
# split0_test_neg_log_loss                                             -0.183644
# split0_test_precision                                                 0.603376
# split1_test_accuracy                                                  0.935524
# split1_test_average_precision                                         0.364337
# split1_test_neg_log_loss                                             -0.185823
# split1_test_precision                                                 0.553191
# split2_test_accuracy                                                  0.938095
# split2_test_average_precision                                         0.365725
# split2_test_neg_log_loss                                             -0.188888
# split2_test_precision                                                 0.609244
# split3_test_accuracy                                                  0.935143
# split3_test_average_precision                                         0.354262
# split3_test_neg_log_loss                                              -0.18846
# split3_test_precision                                                  0.54321
# split4_test_accuracy                                                  0.935524
# split4_test_average_precision                                         0.347433
# split4_test_neg_log_loss                                             -0.190094
# split4_test_precision                                                 0.555066
# split5_test_accuracy                                                  0.936286
# split5_test_average_precision                                         0.380739
# split5_test_neg_log_loss                                              -0.18291
# split5_test_precision                                                 0.569038
# split6_test_accuracy                                                  0.936286
# split6_test_average_precision                                         0.381366
# split6_test_neg_log_loss                                             -0.184406
# split6_test_precision                                                 0.574661
# split7_test_accuracy                                                  0.936857
# split7_test_average_precision                                         0.393766
# split7_test_neg_log_loss                                             -0.183619
# split7_test_precision                                                  0.58159
# split8_test_accuracy                                                  0.937714
# split8_test_average_precision                                         0.382133
# split8_test_neg_log_loss                                             -0.183684
# split8_test_precision                                                 0.595238
# split9_test_accuracy                                                  0.936095
# split9_test_average_precision                                         0.366345
# split9_test_neg_log_loss                                             -0.187201
# split9_test_precision                                                 0.564315
# std_fit_time                                                          0.344663
# std_score_time                                                       0.0106311
# std_test_accuracy                                                  0.000992672
# std_test_average_precision                                           0.0148813
# std_test_neg_log_loss                                               0.00247271
# std_test_precision                                                   0.0211284
#
#                                                                             6  \
# mean_fit_time                                                          44.171
# mean_score_time                                                      0.118278
# mean_test_accuracy                                                   0.934552
# mean_test_average_precision                                          0.354394
# mean_test_neg_log_loss                                              -0.187784
# mean_test_precision                                                  0.532536
# param_GBT__max_depth                                                        9
# param_GBT__n_estimators                                                    25
# params                         {'GBT__max_depth': 9, 'GBT__n_estimators': 25}
# rank_test_accuracy                                                          7
# rank_test_average_precision                                                 6
# rank_test_neg_log_loss                                                      3
# rank_test_precision                                                         7
# split0_test_accuracy                                                 0.935619
# split0_test_average_precision                                        0.380138
# split0_test_neg_log_loss                                             -0.18464
# split0_test_precision                                                0.554622
# split1_test_accuracy                                                 0.934381
# split1_test_average_precision                                         0.35481
# split1_test_neg_log_loss                                            -0.187146
# split1_test_precision                                                 0.52766
# split2_test_accuracy                                                 0.937333
# split2_test_average_precision                                        0.358687
# split2_test_neg_log_loss                                            -0.189076
# split2_test_precision                                                0.598214
# split3_test_accuracy                                                  0.93381
# split3_test_average_precision                                        0.334977
# split3_test_neg_log_loss                                            -0.191183
# split3_test_precision                                                0.515837
# split4_test_accuracy                                                 0.933714
# split4_test_average_precision                                        0.345163
# split4_test_neg_log_loss                                             -0.19053
# split4_test_precision                                                0.514563
# split5_test_accuracy                                                 0.934476
# split5_test_average_precision                                        0.357436
# split5_test_neg_log_loss                                            -0.186048
# split5_test_precision                                                 0.53125
# split6_test_accuracy                                                  0.93381
# split6_test_average_precision                                        0.348953
# split6_test_neg_log_loss                                            -0.188775
# split6_test_precision                                                0.516279
# split7_test_accuracy                                                 0.934095
# split7_test_average_precision                                        0.351333
# split7_test_neg_log_loss                                            -0.187191
# split7_test_precision                                                0.522523
# split8_test_accuracy                                                 0.934286
# split8_test_average_precision                                        0.364582
# split8_test_neg_log_loss                                            -0.184569
# split8_test_precision                                                0.525424
# split9_test_accuracy                                                    0.934
# split9_test_average_precision                                        0.347864
# split9_test_neg_log_loss                                             -0.18868
# split9_test_precision                                                0.518987
# std_fit_time                                                          1.38155
# std_score_time                                                     0.00642676
# std_test_accuracy                                                  0.00106292
# std_test_average_precision                                          0.0115683
# std_test_neg_log_loss                                              0.00215748
# std_test_precision                                                  0.0245508
#
#                                                                             7  \
# mean_fit_time                                                         75.8987
# mean_score_time                                                        0.1719
# mean_test_accuracy                                                   0.933867
# mean_test_average_precision                                          0.347527
# mean_test_neg_log_loss                                              -0.188721
# mean_test_precision                                                  0.514871
# param_GBT__max_depth                                                        9
# param_GBT__n_estimators                                                    50
# params                         {'GBT__max_depth': 9, 'GBT__n_estimators': 50}
# rank_test_accuracy                                                          8
# rank_test_average_precision                                                 7
# rank_test_neg_log_loss                                                      5
# rank_test_precision                                                         8
# split0_test_accuracy                                                 0.935238
# split0_test_average_precision                                        0.362301
# split0_test_neg_log_loss                                            -0.187325
# split0_test_precision                                                0.541667
# split1_test_accuracy                                                 0.933619
# split1_test_average_precision                                        0.360811
# split1_test_neg_log_loss                                            -0.186264
# split1_test_precision                                                0.509025
# split2_test_accuracy                                                 0.935048
# split2_test_average_precision                                        0.336945
# split2_test_neg_log_loss                                            -0.191849
# split2_test_precision                                                0.537594
# split3_test_accuracy                                                 0.932667
# split3_test_average_precision                                        0.329773
# split3_test_neg_log_loss                                            -0.191682
# split3_test_precision                                                0.490196
# split4_test_accuracy                                                 0.933714
# split4_test_average_precision                                        0.333223
# split4_test_neg_log_loss                                            -0.192024
# split4_test_precision                                                0.512821
# split5_test_accuracy                                                 0.933143
# split5_test_average_precision                                        0.351965
# split5_test_neg_log_loss                                             -0.18654
# split5_test_precision                                                     0.5
# split6_test_accuracy                                                 0.934571
# split6_test_average_precision                                        0.345281
# split6_test_neg_log_loss                                            -0.189552
# split6_test_precision                                                0.531646
# split7_test_accuracy                                                    0.934
# split7_test_average_precision                                        0.346614
# split7_test_neg_log_loss                                            -0.187363
# split7_test_precision                                                0.518672
# split8_test_accuracy                                                 0.933619
# split8_test_average_precision                                        0.357497
# split8_test_neg_log_loss                                            -0.185637
# split8_test_precision                                                0.508961
# split9_test_accuracy                                                 0.933048
# split9_test_average_precision                                         0.35086
# split9_test_neg_log_loss                                            -0.188973
# split9_test_precision                                                0.498127
# std_fit_time                                                          1.27204
# std_score_time                                                       0.011546
# std_test_accuracy                                                 0.000810588
# std_test_average_precision                                          0.0107824
# std_test_neg_log_loss                                              0.00233069
# std_test_precision                                                  0.0164737
#
#                                                                              8
# mean_fit_time                                                          111.161
# mean_score_time                                                       0.217594
# mean_test_accuracy                                                    0.933181
# mean_test_average_precision                                           0.339908
# mean_test_neg_log_loss                                               -0.191175
# mean_test_precision                                                   0.500386
# param_GBT__max_depth                                                         9
# param_GBT__n_estimators                                                    100
# params                         {'GBT__max_depth': 9, 'GBT__n_estimators': 100}
# rank_test_accuracy                                                           9
# rank_test_average_precision                                                  9
# rank_test_neg_log_loss                                                       7
# rank_test_precision                                                          9
# split0_test_accuracy                                                  0.933524
# split0_test_average_precision                                          0.35562
# split0_test_neg_log_loss                                             -0.188175
# split0_test_precision                                                 0.507194
# split1_test_accuracy                                                  0.933048
# split1_test_average_precision                                         0.347449
# split1_test_neg_log_loss                                             -0.189239
# split1_test_precision                                                 0.498246
# split2_test_accuracy                                                  0.934286
# split2_test_average_precision                                         0.330847
# split2_test_neg_log_loss                                             -0.194502
# split2_test_precision                                                 0.521898
# split3_test_accuracy                                                  0.932571
# split3_test_average_precision                                         0.319329
# split3_test_neg_log_loss                                             -0.195189
# split3_test_precision                                                 0.488806
# split4_test_accuracy                                                   0.93181
# split4_test_average_precision                                         0.326856
# split4_test_neg_log_loss                                              -0.19433
# split4_test_precision                                                 0.472656
# split5_test_accuracy                                                  0.933714
# split5_test_average_precision                                         0.347214
# split5_test_neg_log_loss                                             -0.187623
# split5_test_precision                                                  0.51049
# split6_test_accuracy                                                  0.933714
# split6_test_average_precision                                         0.340459
# split6_test_neg_log_loss                                             -0.192024
# split6_test_precision                                                 0.510791
# split7_test_accuracy                                                  0.932571
# split7_test_average_precision                                          0.32823
# split7_test_neg_log_loss                                              -0.19175
# split7_test_precision                                                  0.48913
# split8_test_accuracy                                                  0.933619
# split8_test_average_precision                                          0.34645
# split8_test_neg_log_loss                                             -0.188757
# split8_test_precision                                                 0.508143
# split9_test_accuracy                                                  0.932952
# split9_test_average_precision                                         0.356632
# split9_test_neg_log_loss                                             -0.190165
# split9_test_precision                                                 0.496503
# std_fit_time                                                           20.9408
# std_score_time                                                       0.0478674
# std_test_accuracy                                                  0.000692296
# std_test_average_precision                                           0.0122157
# std_test_neg_log_loss                                               0.00265374
# std_test_precision                                                   0.0135241

# %%
pd.DataFrame(grid_search.cv_results_)[['mean_fit_time', 'param_GBT__max_depth', 'param_GBT__n_estimators',
                                      'mean_test_accuracy', 'mean_test_precision', 'mean_test_average_precision',
                                      'mean_test_neg_log_loss']].T#.to_csv('grid_search_cv_results.csv')
# Out:
#                                     0         1         2         3         4  \
# mean_fit_time                 2.77157   4.58212    8.9941   7.31363   15.1026
# param_GBT__max_depth                2         2         2         5         5
# param_GBT__n_estimators            25        50       100        25        50
# mean_test_accuracy             0.9358  0.937057  0.937238  0.936543  0.936657
# mean_test_precision          0.615378  0.621309  0.606148    0.6072  0.582789
# mean_test_average_precision  0.344293  0.362574  0.368537  0.372784  0.375265
# mean_test_neg_log_loss      -0.194948 -0.191332 -0.189446 -0.188682 -0.186317
#
#                                     5         6         7         8
# mean_fit_time                 29.6847    44.171   75.8987   111.161
# param_GBT__max_depth                5         9         9         9
# param_GBT__n_estimators           100        25        50       100
# mean_test_accuracy           0.936533  0.934552  0.933867  0.933181
# mean_test_precision          0.574893  0.532536  0.514871  0.500386
# mean_test_average_precision  0.372893  0.354394  0.347527  0.339908
# mean_test_neg_log_loss      -0.185873 -0.187784 -0.188721 -0.191175

# %%
#pd.DataFrame(grid_sesarch.cv_results_).columns

# %%
grid_search.best_estimator_
# Out:
# Pipeline(memory=None,
#          steps=[('impute_mean',
#                  ColumnTransformer(n_jobs=None, remainder='drop',
#                                    sparse_threshold=0.3,
#                                    transformer_weights=None,
#                                    transformers=[('scalar imputing mean',
#                                                   SimpleImputer(add_indicator=False,
#                                                                 copy=True,
#                                                                 fill_value=None,
#                                                                 missing_values=nan,
#                                                                 strategy='mean',
#                                                                 verbose=0),
#                                                   Index(['id', 'RevolvingUtilizationOfUnsecuredLines', 'age',
#        'NumberOfTime30...
#                                             learning_rate=0.1, loss='deviance',
#                                             max_depth=5, max_features=None,
#                                             max_leaf_nodes=None,
#                                             min_impurity_decrease=0.0,
#                                             min_impurity_split=None,
#                                             min_samples_leaf=1,
#                                             min_samples_split=2,
#                                             min_weight_fraction_leaf=0.0,
#                                             n_estimators=50,
#                                             n_iter_no_change=None,
#                                             presort='auto', random_state=None,
#                                             subsample=1.0, tol=0.0001,
#                                             validation_fraction=0.1, verbose=0,
#                                             warm_start=False))],
#          verbose=False)

# %% [markdown]
# # Feature Importance

# %%
feature_imp = pd.DataFrame({'column': X_train.columns,
                            'feature_importance': grid_search.best_estimator_.named_steps["GBT"].feature_importances_})
feature_imp = feature_imp.sort_values('feature_importance', ascending=False)
#feature_imp.to_csv('feature_importance_90k_lapse.csv')

# %%
feature_imp.head(15)
# Out:
#                                   column  feature_importance
# 7                NumberOfTimes90DaysLate            0.515592
# 3   NumberOfTime30-59DaysPastDueNotWorse            0.147328
# 1   RevolvingUtilizationOfUnsecuredLines            0.103022
# 9   NumberOfTime60-89DaysPastDueNotWorse            0.092474
# 2                                    age            0.036528
# 5                          MonthlyIncome            0.027886
# 6        NumberOfOpenCreditLinesAndLoans            0.021263
# 0                                     id            0.019938
# 8           NumberRealEstateLoansOrLines            0.017090
# 4                              DebtRatio            0.010905
# 10                    NumberOfDependents            0.007975

# %% [markdown]
# # Save the Model Output

# %%
dump(grid_search, '{}.joblib'.format(model_name))
# Out:
# ['credit_default.joblib.joblib']

# %% [markdown]
# # Write the Predictions

# %% [markdown]
# Evaluate on the Test set

# %%
from sklearn.metrics import average_precision_score, log_loss, accuracy_score, precision_score
print('Test ({} samples) performance metrics'.format(len(y_test)))
print('average precision: {}'.format(average_precision_score(y_test, 
                                                            grid_search.predict_proba(X_test)[:, 1])))
print('log loss: {}'.format(log_loss(y_test, grid_search.predict_proba(X_test)[:, 1])))
print('accuracy: {}'.format(accuracy_score(y_test, grid_search.predict(X_test))))
print('precision: {}'.format(precision_score(y_test, grid_search.predict(X_test))))
# Out:
# Test (45000 samples) performance metrics
# average precision: 0.39835852319365445
# log loss: 0.18009017599069507
# accuracy: 0.9371111111111111
# precision: 0.5942184154175589

# %% [markdown]
# Save the results

# %%
test_scores = pd.DataFrame({'id': X_test['id'],
                            'probability': grid_search.predict_proba(X_test)[:, 1],
                            'prediction': grid_search.predict(X_test),
                             'actual': y_test})

# %%
test_scores.head()
# Out:
#         actual      id  prediction  probability
# 102264       0  102265           0     0.016047
# 149055       0  149056           0     0.039565
# 94569        0   94570           0     0.027330
# 22569        0   22570           0     0.033487
# 13656        0   13657           0     0.027812

# %%
#test_scores_with_data = pd.concat([test_scores, X_train.drop('id', axis=1)], axis=1)

# %%
#test_scores_with_data.head()

# %%
#test_scores_with_data.to_csv('{}_scores_with_data.csv'.format(model_name))

# %% [markdown]
# # Predcitions Confusion Matrix

# %%
cm = confusion_matrix(test_scores['actual'], test_scores['prediction'])
cm
# Out:
# array([[41615,   379],
#        [ 2451,   555]])

# %%
total = len(test_scores)
perc_vals = [[cm[0][0]/total*100, cm[0][1]/total*100], 
             [cm[1][0]/total*100, cm[1][1]/total*100]]
perc_vals
# Out:
# [[92.47777777777777, 0.8422222222222222],
#  [5.446666666666666, 1.2333333333333334]]
